# %% [markdown]
#                                                                                   Business Context:
# No more than 4 dot points on presentation
#
#
# Highlight the problem – Tell us what you are going to talk about
#
#
# To get the context of any problem, you need to do some research on the web
#
#
# Give us statistic facts
#
#
# Tell us why this problem needs to be looked at
#
#
# Business Question:
# If it is a linear regression problem, ask "Can we predict the temperature for tomorrow?", or "Can we estimate someone's salary based on their experience?", "Can we forecast the price of a stock next week?"
#
#
# If its a classification problem, ask " Can we determine if an email is spam or not spam?", "Can we predict if the cancer is malignant or not?", "Can we predict if rap is popular or not?"
#
#
#
# Data Pipeline:
# This is where you show series of steps of how you are going to answer your business question. Make sure you have a nice diagram with arrows or you can list your steps.
#
#
#
# EDAs:
# Show us your findings and trends in your dataset. Make sure it relates to your storyline! You can show heat map if you want!
#
#
#
#
# Modelling:
# Show data preprocessing such as one-hot encoding, label encoding, splitting the dataset
# Show algorithms aka models for comparision: SVM, Logistic Regression, KNN, Random Forest
# (make sure the model is compatiable with your type of problem)
#  Show feature selection in this section to tell us what features you will put in ur model
#
#
#
# Model Interpretation:
#
#
# We want to see the performance metrics
# Linear Regression - show R2, MAE and RMSE
# Classification- show F1 score, Recall, Accuracy
# Show which model did the best in answering your business question, and show ROC curve to see how well the model performed
#
#
# Summary/Next Steps:
# Summarise your findings: did it answer the business question and how?
# Next Steps: Should we get more data? Any additional data source? Ready for deployment? Does it need any improvement, what sort of improvement?

# %% [markdown]
# ### Kaggle : Netflix stock

# %% [markdown]
# ### Hilight :
#
#
# - The dataset contains historical data starting from February 5, 2018,
# with entries detailing stock performance over time.
#
# - It includes daily metrics for Netflix's stock (NFLX)
# such as Open, High, Low, Close, and Adjusted Close prices,
# providing a comprehensive view of the stock's daily performance.
#
# - The dataset also captures the trading volume for each day,
# \indicating the number of shares traded.
#
# - Each row represents a single day's trading data for Netflix's stock,
# structured in a tabular format with columns for Date, Open, High, Low, Close, Adjusted Close,
# and Volume. This structured format allows for easy analysis of stock performance over time.

# %% [markdown]
# ### Business question : How does the trading volume of Netflix's stock impact its closing price?

# %% [markdown]
# ### EDA:

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\sharo\Desktop/iod/Mini project 2\NFLX.csv",header =0 )

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
df.info
# Out:
# <bound method DataFrame.info of             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
# ...

# %%
df.shape
# Out:
# (1009, 6)

# %%
df.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...                ...         ...         ...         ...         ...
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# ...

# %%
plt.figure(figsize=(14, 7))
plt.plot(df['Date'], df['Close'], label='Close Price', color='blue')
plt.title('Netflix Closing Price Trend')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.legend()
plt.show()

# %% [markdown]
# patterns provide insights into the stock's performance over
# the observed period and can help identify potential factors influencing its value.

# %%
# Volatility
df['Daily Returns'] = df['Adj Close'].pct_change()

plt.figure(figsize=(14, 7))
plt.plot(df['Date'], df['Daily Returns'], label='Daily Returns', color='red')
plt.title('Netflix Daily Returns (Volatility)')
plt.xlabel('Date')
plt.ylabel('Daily Returns')
plt.legend()
plt.show()

# %% [markdown]
# Days with high volatility are evident through larger spikes in the daily returns
#
# showing  periods of increased risk and opportunity for traders

# %%
df['Daily Returns'] = df['Adj Close'].pct_change()

# %%
correlation_matrix = df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Daily Returns']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix of Netflix Stock Features')
plt.show()

# %% [markdown]
# - high positive correlation between the Open, High, Low, Close, and Adjusted Close prices
# - dailly return  show low corr.not strongly dependent on the day's trading volume or the opening/closing prices

# %% [markdown]
# calculate:

# %%
df['Price_Range'] = df['High'] - df['Low']

# %%
df['Pct_Change'] = ((df['Close'] - df['Open']) / df['Open']) * 100

# %%
label : High,low,medium  volatility

# %%
x = volume # scaler 
y = close # train 

# test slipt 
# clasfi: logistic
# vector machine 
# random forest 

# confuse matric : ROC AUC 
# accuracy recall and F1 score

# %%
Data Traini : Actual Vs samples

# %%
time
